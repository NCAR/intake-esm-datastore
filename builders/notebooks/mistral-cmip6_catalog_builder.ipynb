# %%
import pandas as pd
import fnmatch
import dask.dataframe as dd
from intake.source.utils import reverse_format
import os
import re
import subprocess
from tqdm.auto import tqdm
from pathlib import Path
import shutil
import numpy as np

# %% [markdown]
# ## Create text file containing all files available

# %%
def get_file_list(persist_path):
    persist_path = Path(persist_path)
    persist_path.mkdir(exist_ok=True)
    root = Path("/work/ik1017/CMIP6/data/CMIP6")
    dirs = [x for x in root.iterdir() if x.is_dir()]
    for directory in tqdm(dirs):
        print(directory)
        stem = directory.stem
        f = open(f"{persist_path}/{stem}.txt", "w")
        cmd = ["find", "-L", directory.as_posix(), "-name", "*.nc"]
        p = subprocess.Popen(cmd, stderr=subprocess.PIPE, stdout=f)
        p.wait()

# %%
persist_path = "./CMIP6_filelist"
get_file_list(persist_path)
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# /work/ik1017/CMIP6/data/CMIP6/GeoMIP
# /work/ik1017/CMIP6/data/CMIP6/HighResMIP
# /work/ik1017/CMIP6/data/CMIP6/DAMIP
# /work/ik1017/CMIP6/data/CMIP6/C4MIP
# /work/ik1017/CMIP6/data/CMIP6/ScenarioMIP
# /work/ik1017/CMIP6/data/CMIP6/ISMIP6
# /work/ik1017/CMIP6/data/CMIP6/PMIP
# /work/ik1017/CMIP6/data/CMIP6/GMMIP
# /work/ik1017/CMIP6/data/CMIP6/AerChemMIP
# /work/ik1017/CMIP6/data/CMIP6/LS3MIP
# /work/ik1017/CMIP6/data/CMIP6/CMIP
# /work/ik1017/CMIP6/data/CMIP6/RFMIP
# /work/ik1017/CMIP6/data/CMIP6/DCPP
# /work/ik1017/CMIP6/data/CMIP6/FAFMIP
# /work/ik1017/CMIP6/data/CMIP6/OMIP
# /work/ik1017/CMIP6/data/CMIP6/CDRMIP
# /work/ik1017/CMIP6/data/CMIP6/PAMIP
# /work/ik1017/CMIP6/data/CMIP6/LUMIP
# /work/ik1017/CMIP6/data/CMIP6/CFMIP

# %% [markdown]
# ## Extract attributes of a file using information from CMI6 DRS.
#
#
# References
#  1. CMIP6 DRS: http://goo.gl/v1drZl
#  2. Controlled Vocabularies (CVs) for use in CMIP6:
#     https://github.com/WCRP-CMIP/CMIP6_CVs
#
#
# Directory structure =
# ```<mip_era>/
#     <activity_id>/
#         <institution_id>/
#             <source_id>/
#                 <experiment_id>/
#                     <member_id>/
#                         <table_id>/
#                             <variable_id>/
#                                 <grid_label>/
#                                     <version>
# ```
# file name =
# ```<variable_id>_<table_id>_<source_id>_<experiment_id >_<member_id>_<grid_label>[_<time_range>].nc```
# For time-invariant fields, the last segment (time_range) above is omitted.
# Example when there is no sub-experiment: `tas_Amon_GFDL-CM4_historical_r1i1p1f1_gn_196001-199912.nc`
# Example with a sub-experiment:   `pr_day_CNRM-CM6-1_dcppA-hindcast_s1960-r2i1p1f1_gn_198001-198412.nc`

# %%
activity_ids = list(Path(persist_path).rglob("*.txt"))
activity_ids = [activity_id.stem for activity_id in activity_ids]
activity_ids
# Out:
# ['CDRMIP',
#  'PAMIP',
#  'ISMIP6',
#  'ScenarioMIP',
#  'DCPP',
#  'RFMIP',
#  'LS3MIP',
#  'FAFMIP',
#  'DAMIP',
#  'C4MIP',
#  'OMIP',
#  'LUMIP',
#  'AerChemMIP',
#  'CMIP',
#  'GeoMIP',
#  'HighResMIP',
#  'PMIP',
#  'GMMIP',
#  'CFMIP']

# %%
df = dd.read_csv(f"{persist_path}/*.txt", header=None).compute()
df.columns = ["path"]
df.head()
# Out:
#                                                 path
# 0  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 1  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 2  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 3  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 4  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...

# %% [markdown]
# - 5.11.2019: 1868201

# %%
len(df)
# Out:
# 1868201

# %%
# new
len(df)
# Out:
# 1868201

# %%
def _reverse_filename_format(file_basename, filename_template=None, gridspec_template=None):
    """
    Uses intake's ``reverse_format`` utility to reverse the string method format.
    Given format_string and resolved_string, find arguments
    that would give format_string.format(arguments) == resolved_string
    """
    try:
        return reverse_format(filename_template, file_basename)
    except ValueError:
        try:
            return reverse_format(gridspec_template, file_basename)
        except:
            print(
                f'Failed to parse file: {file_basename} using patterns: {filename_template} and {gridspec_template}'
            )
            return {}


def _extract_attr_with_regex(input_str, regex, strip_chars=None):
    pattern = re.compile(regex, re.IGNORECASE)
    match = re.findall(pattern, input_str)
    if match:
        match = max(match, key=len)
        if strip_chars:
            match = match.strip(strip_chars)

        else:
            match = match.strip()

        return match

    else:
        return None


exclude_patterns = ['*/files/*', '*/latest/*']


def _filter_func(path):
    return not any(fnmatch.fnmatch(path, pat=exclude_pattern) for exclude_pattern in exclude_patterns)

# %%
# %%time
files = df.path.tolist()
filelist = list(filter(_filter_func, files))
# Out:
# CPU times: user 7.45 s, sys: 0 ns, total: 7.45 s
# Wall time: 7.44 s

# %%
len(filelist)
# Out:
# 1868201

# %%
def get_attrs(filepath):
    basename = os.path.basename(filepath)
    dirname = os.path.dirname(filepath)
    filename_template = (
        '{variable_id}_{table_id}_{source_id}_{experiment_id}_{member_id}_{grid_label}_{time_range}.nc'
    )

    gridspec_template = '{variable_id}_{table_id}_{source_id}_{experiment_id}_{member_id}_{grid_label}.nc'

    f = _reverse_filename_format(
        basename, filename_template=filename_template, gridspec_template=gridspec_template
    )

    fileparts = {}
    fileparts.update(f)
    parent = os.path.dirname(filepath).strip('/')
    parent_split = parent.split(f"/{fileparts['source_id']}/")
    part_1 = parent_split[0].strip('/').split('/')
    grid_label = parent.split(f"/{fileparts['variable_id']}/")[1].strip('/').split('/')[0]
    fileparts['grid_label'] = grid_label
    fileparts['activity_id'] = part_1[-2]
    fileparts['institution_id'] = part_1[-1]
    version_regex = r'v\d{4}\d{2}\d{2}|v\d{1}'
    version = _extract_attr_with_regex(parent, regex=version_regex) or 'v0'
    fileparts['version'] = version
    fileparts['path'] = filepath
    return fileparts

# %%
# %%time
entries = list(map(get_attrs, filelist))
# Out:
# CPU times: user 51.6 s, sys: 1.49 s, total: 53.1 s
# Wall time: 53.1 s

# %%
entries[0]
# Out:
# {'variable_id': 'mrsos',
#  'table_id': 'Lmon',
#  'source_id': 'GFDL-ESM4',
#  'experiment_id': 'piClim-aer',
#  'member_id': 'r1i1p1f1',
#  'grid_label': 'gr1',
#  'time_range': '000101-003012',
#  'activity_id': 'AerChemMIP',
#  'institution_id': 'NOAA-GFDL',
#  'version': 'v20180701',
#  'path': '/work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-GFDL/GFDL-ESM4/piClim-aer/r1i1p1f1/Lmon/mrsos/gr1/v20180701/mrsos_Lmon_GFDL-ESM4_piClim-aer_r1i1p1f1_gr1_000101-003012.nc'}

# %%
len(entries)
# Out:
# 1868201

# %%
df1 = pd.DataFrame(entries)
df1.head()
# Out:
#   variable_id table_id  source_id experiment_id member_id grid_label  \
# 0       mrsos     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 1        mrso     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 2        mrro     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 3       mrros     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 4        rlus     Amon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
#
#       time_range activity_id institution_id    version  \
# 0  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 1  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 2  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 3  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 4  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
#
#                                                 path
# 0  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 1  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 2  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 3  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 4  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...

# %%
len(df1)
# Out:
# 1868201

# %%
# Some entries are invalid
invalids = df1[~df1.activity_id.isin(activity_ids)]
df = df1[df1.activity_id.isin(activity_ids)]
invalids
# Out:
#         variable_id table_id   source_id experiment_id member_id grid_label  \
# 14173          orog       fx  piClim-SO2    NorESM2-LM  r1i1p1f1         gn
# 14174     areacella       fx  piClim-SO2    NorESM2-LM  r1i1p1f1         gn
# 14175         sftlf       fx  piClim-SO2    NorESM2-LM  r1i1p1f1         gn
# 14179     areacella       fx   piClim-OC    NorESM2-LM  r1i1p1f1         gn
# 14180         sftlf       fx   piClim-OC    NorESM2-LM  r1i1p1f1         gn
# ...             ...      ...         ...           ...       ...        ...
# 1432782          uo     Omon   land-hist   GISS-E2-1-G  r4i1p1f1         gn
# 1432783          uo     Omon   land-hist   GISS-E2-1-G  r4i1p1f1         gn
# 1432784          uo     Omon   land-hist   GISS-E2-1-G  r4i1p1f1         gn
# 1461577   areacella       fx  piClim-ghg    NorESM2-LM  r1i1p1f1         gn
# 1461578       sftlf       fx  piClim-ghg    NorESM2-LM  r1i1p1f1         gn
#
#             time_range activity_id institution_id    version  \
# 14173              NaN         NCC     NorESM2-LM  v20190815
# 14174              NaN         NCC     NorESM2-LM  v20190815
# 14175              NaN         NCC     NorESM2-LM  v20190815
# 14179              NaN         NCC     NorESM2-LM  v20190815
# 14180              NaN         NCC     NorESM2-LM  v20190815
# ...                ...         ...            ...        ...
# 1432782  187101-189012   NASA-GISS    GISS-E2-1-G  v20180914
# 1432783  201101-201412   NASA-GISS    GISS-E2-1-G  v20180914
# 1432784  193101-195012   NASA-GISS    GISS-E2-1-G  v20180914
# 1461577            NaN         NCC     NorESM2-LM  v20190815
# 1461578            NaN         NCC     NorESM2-LM  v20190815
#
#                                                       path
# 14173    /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/
nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vo/gn/v20180914/vo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_189101-191012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vo/gn/v20180914/vo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_195101-197012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_195101-197012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_193101-195012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_199101-201012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_191101-193012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_189101-191012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_187101-189012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_185001-187012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_201101-201412.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/vmo/gn/v20180914/vmo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_197101-199012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_191101-193012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_193101-195012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_189101-191012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_187101-189012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_195101-197012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_185001-187012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_201101-201412.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_197101-199012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/masso/gn/v20180914/masso_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_199101-201012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_201101-201412.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_189101-191012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_197101-199012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_199101-201012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_187101-189012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_193101-195012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_191101-193012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_185001-187012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/thetao/gn/v20180914/thetao_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_195101-197012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_195101-197012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_191101-193012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_185001-187012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_197101-199012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_199101-201012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_189101-191012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_187101-189012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_201101-201412.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/LUMIP/NASA-GISS/GISS-E2-1-G/land-hist/r4i1p1f1/Omon/uo/gn/v20180914/uo_Omon_land-hist_GISS-E2-1-G_r4i1p1f1_gn_193101-195012.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/RFMIP/NCC/NorESM2-LM/piClim-ghg/r1i1p1f1/fx/areacella/gn/v20190815/areacella_fx_piClim-ghg_NorESM2-LM_r1i1p1f1_gn.nc',
#  '/work/ik1017/CMIP6/data/CMIP6/RFMIP/NCC/NorESM2-LM/piClim-ghg/r1i1p1f1/fx/sftlf/gn/v20190815/sftlf_fx_piClim-ghg_NorESM2-LM_r1i1p1f1_gn.nc']

# %%
grpby = list(set(df.columns.tolist()) - {'path', 'version'})
groups = df.groupby(grpby)

# %%
# %%time
idx_to_remove = []
for _, group in groups:
    if group.version.nunique() > 1:
        idx_to_remove.extend(group.sort_values(by=['version'], ascending=False).index[1:].values.tolist())
# Out:
# CPU times: user 11min 55s, sys: 13.1 s, total: 12min 8s
# Wall time: 11min 48s

# %%
len(idx_to_remove)
# Out:
# 62389

# %%
len(df)
# Out:
# 1867298

# %%
df = df.drop(index=idx_to_remove)
len(df)
# Out:
# 1804909

# %%
df["dcpp_init_year"] = df.member_id.map(lambda x: float(x.split("-")[0][1:] if x.startswith("s") else np.nan))
df["member_id"] = df["member_id"].map(lambda x: x.split("-")[-1] if x.startswith("s") else x)
df.head()
# Out:
#   variable_id table_id  source_id experiment_id member_id grid_label  \
# 0       mrsos     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 1        mrso     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 2        mrro     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 3       mrros     Lmon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
# 4        rlus     Amon  GFDL-ESM4    piClim-aer  r1i1p1f1        gr1
#
#       time_range activity_id institution_id    version  \
# 0  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 1  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 2  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 3  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
# 4  000101-003012  AerChemMIP      NOAA-GFDL  v20180701
#
#                                                 path  dcpp_init_year
# 0  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...             NaN
# 1  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...             NaN
# 2  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...             NaN
# 3  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...             NaN
# 4  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...             NaN

# %%
columns = [
    "activity_id",
    "institution_id",
    "source_id",
    "experiment_id",
    "member_id",
    "table_id",
    "variable_id",
    "grid_label",
    "dcpp_init_year",
    "version",
    "time_range",
    "path",
]
df = df[columns]
df.head()
# Out:
#   activity_id institution_id  source_id experiment_id member_id table_id  \
# 0  AerChemMIP      NOAA-GFDL  GFDL-ESM4    piClim-aer  r1i1p1f1     Lmon
# 1  AerChemMIP      NOAA-GFDL  GFDL-ESM4    piClim-aer  r1i1p1f1     Lmon
# 2  AerChemMIP      NOAA-GFDL  GFDL-ESM4    piClim-aer  r1i1p1f1     Lmon
# 3  AerChemMIP      NOAA-GFDL  GFDL-ESM4    piClim-aer  r1i1p1f1     Lmon
# 4  AerChemMIP      NOAA-GFDL  GFDL-ESM4    piClim-aer  r1i1p1f1     Amon
#
#   variable_id grid_label  dcpp_init_year    version     time_range  \
# 0       mrsos        gr1             NaN  v20180701  000101-003012
# 1        mrso        gr1             NaN  v20180701  000101-003012
# 2        mrro        gr1             NaN  v20180701  000101-003012
# 3       mrros        gr1             NaN  v20180701  000101-003012
# 4        rlus        gr1             NaN  v20180701  000101-003012
#
#                                                 path
# 0  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 1  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 2  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 3  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...
# 4  /work/ik1017/CMIP6/data/CMIP6/AerChemMIP/NOAA-...

# %%
# !pwd
# Out:
# /mnt/lustre01/pf/zmaw/m300524/intake-esm-datastore/builders

# %%
df.to_csv("../catalogs/mistral-cmip6.csv.gz", compression="gzip", index=False)

# %%
df.memory_usage(index=True).sum()
# Out:
# 187710536

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1804909 entries, 0 to 1868200
# Data columns (total 12 columns):
# activity_id       object
# institution_id    object
# source_id         object
# experiment_id     object
# member_id         object
# table_id          object
# variable_id       object
# grid_label        object
# dcpp_init_year    float64
# version           object
# time_range        object
# path              object
# dtypes: float64(1), object(11)
# memory usage: 1.5 GB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1804909 entries, 0 to 1868200
# Data columns (total 12 columns):
# activity_id       object
# institution_id    object
# source_id         object
# experiment_id     object
# member_id         object
# table_id          object
# variable_id       object
# grid_label        object
# dcpp_init_year    float64
# version           object
# time_range        object
# path              object
# dtypes: float64(1), object(11)
# memory usage: 179.0+ MB
