# %%
from dask.distributed import Client
import multiprocessing
ncpu = multiprocessing.cpu_count()
threads = 6
nworker = ncpu//threads
print(ncpu, threads, nworker)
# Out:
# 48 6 8

# %%
client = Client(processes=False, threads_per_worker=threads, n_workers=nworker, memory_limit='256GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:33165' processes=8 threads=48, memory=515.40 GB>

# %%
import pandas as pd
import fnmatch
import dask.dataframe as dd
from intake.source.utils import reverse_format
import os
import re
import subprocess
from tqdm.auto import tqdm
from pathlib import Path
import shutil
import numpy as np

# %% [markdown]
# ## Create text file containing all files available

# %%
def get_file_list(persist_path):
    root = Path("/work/mh1007/CMOR/MPI-GE")
    p_path = Path(persist_path)
    p_path.mkdir(exist_ok=True)
    dirs = [x for x in root.iterdir() if x.is_dir()]
    for directory in tqdm(dirs):
        print(directory)
        stem = directory.stem
        f = open(f"{persist_path}/{stem}.txt", "w")
        cmd = ["find", "-L", directory.as_posix(), "-name", "*.nc"]
        p = subprocess.Popen(cmd, stderr=subprocess.PIPE, stdout=f)
        p.wait()

# %%
persist_path = "./MPIGE_filelist"
get_file_list(persist_path)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# /work/mh1007/CMOR/MPI-GE/output1

# %% [markdown]
# ## Extract attributes of a file using information from CMIP5 DRS.
#
#
#
# Reference:
# - CMIP5 DRS: https://pcmdi.llnl.gov/mips/cmip5/docs/cmip5_data_reference_syntax.pdf?id=27
#
# Directory:
# ```
#   <activity>/
#     <product>/
#         <institute>/
#             <model>/
#                 <experiment>/
#                     <frequency>/
#                         <modeling realm>/
#                             <MIP table>/
#                                 <ensemble member>/
#                                     <version number>/
#                                         <variable name>/
#                                             <CMOR filename>.nc
# ```
#
# CMOR filename: `<variable name>_<MIP table>_<model>_<experiment>_ <ensemble member>[_<temporal subset>][_<geographical info>].nc`
# """

# %%
products = list(Path(persist_path).rglob("*.txt"))
products = [product.stem for product in products]
products
# Out:
# ['output1']

# %%
df = dd.read_csv(f"{persist_path}/*.txt", header=None).compute()
df.columns = ["path"]
df.head()
# Out:
#                                                 path
# 0  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 1  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 2  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 3  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 4  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...

# %% [markdown]
# 06/11/2019: 70124

# %%
len(df)
# Out:
# 70124

# %%
def _reverse_filename_format(file_basename, filename_template=None, gridspec_template=None):
    """
    Uses intake's ``reverse_format`` utility to reverse the string method format.
    Given format_string and resolved_string, find arguments
    that would give format_string.format(arguments) == resolved_string
    """
    try:
        return reverse_format(filename_template, file_basename)
    except ValueError:
        try:
            return reverse_format(gridspec_template, file_basename)
        except:
            print(
                f'Failed to parse file: {file_basename} using patterns: {filename_template} and {gridspec_template}'
            )
            return {}
            
def _extract_attr_with_regex(input_str, regex, strip_chars=None):
    pattern = re.compile(regex, re.IGNORECASE)
    match = re.findall(pattern, input_str)
    if match:
        match = max(match, key=len)
        if strip_chars:
            match = match.strip(strip_chars)

        else:
            match = match.strip()

        return match

    else:
        return None
    

exclude_patterns = ['*/files/*', '*/latest/*']
def _filter_func(path):
    return not any(
        fnmatch.fnmatch(path, pat=exclude_pattern) for exclude_pattern in exclude_patterns
    )

# %%
# %%time
files = df.path.tolist()
filelist = list(filter(_filter_func, files))
# Out:
# CPU times: user 323 ms, sys: 1 ms, total: 324 ms
# Wall time: 319 ms

# %%
len(filelist)
# Out:
# 70124

# %%
def get_attrs(filepath):
    """ Extract attributes of a file using information from CMIP5 DRS.
    Notes
    -----
    Reference:
    - CMIP5 DRS: https://pcmdi.llnl.gov/mips/cmip5/docs/cmip5_data_reference_syntax.pdf?id=27
    """

    fileparts = {}

    freq_regex = r'/3hr/|/6hr/|/day/|/fx/|/mon/|/monClim/|/subhr/|/yr/'
    realm_regex = r'aerosol|atmos|land|landIce|ocean|ocnBgchem|seaIce'
    version_regex = r'v\d{4}\d{2}\d{2}|v\d{1}'

    file_basename = os.path.basename(filepath)
    fileparts['path'] = filepath

    filename_template = (
        '{variable}_{mip_table}_{model}_{experiment}_{ensemble_member}_{temporal_subset}.nc'
    )
    gridspec_template = '{variable}_{mip_table}_{model}_{experiment}_{ensemble_member}.nc'
    f = _reverse_filename_format(
        file_basename, filename_template=filename_template, gridspec_template=gridspec_template
    )
    fileparts.update(f)

    frequency = _extract_attr_with_regex(
        filepath, regex=freq_regex, strip_chars='/'
    )
    realm = _extract_attr_with_regex(filepath, regex=realm_regex)
    version = _extract_attr_with_regex(filepath, regex=version_regex) or 'v0'
    fileparts['frequency'] = frequency
    fileparts['modeling_realm'] = realm
    fileparts['version'] = version
    try:
        part1, part2 = os.path.dirname(filepath).split(fileparts['experiment'])
        part1 = part1.strip("/").split("/")
        fileparts['institute'] = part1[-2]
        fileparts['product_id'] = part1[-3]
    except Exception:
        print(fileparts)
    

    return fileparts

# %%
get_attrs(filelist[0])
# Out:
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/piControl/mon/atmos/prsn/r001i1850p3/v20190123/prsn_Amon_MPI-ESM_piControl_r001i1850p3_310001-319912.nc',
#  'variable': 'prsn',
#  'mip_table': 'Amon',
#  'model': 'MPI-ESM',
#  'experiment': 'piControl',
#  'ensemble_member': 'r001i1850p3',
#  'temporal_subset': '310001-319912',
#  'frequency': 'mon',
#  'modeling_realm': 'atmos',
#  'version': 'v20190123',
#  'institute': 'MPI-M',
#  'product_id': 'output1'}

# %%
# %%time
entries = list(map(get_attrs, filelist))
# Out:
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r036i2005p3/ph_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r036i2005p3/o2_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r036i2005p3/dcalc_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r036i2005p3/bfe_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r036i2005p3/co3_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r036i2005p3/co3satcalc_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r036i2005p3/no3_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r036i2005p3/talk_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r036i2005p3/si_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_036/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r036i2005p3/po4_Omon_MPI-ESM_rr036i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr036i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r063i2005p3/ph_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r063i2005p3/o2_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r063i2005p3/dcalc_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r063i2005p3/bfe_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r063i2005p3/co3_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r063i2005p3/co3satcalc_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r063i2005p3/no3_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r063i2005p3/talk_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r063i2005p3/si_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_063/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r063i2005p3/po4_Omon_MPI-ESM_rr063i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr063i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r037i2005p3/ph_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r037i2005p3/o2_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r037i2005p3/dcalc_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r037i2005p3/bfe_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r037i2005p3/co3_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r037i2005p3/co3satcalc_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r037i2005p3/no3_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r037i2005p3/talk_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r037i2005p3/si_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_037/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r037i2005p3/po4_Omon_MPI-ESM_rr037i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr037i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r033i2005p3/ph_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r033i2005p3/o2_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r033i2005p3/dcalc_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r033i2005p3/bfe_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r033i2005p3/co3_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r033i2005p3/co3satcalc_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r033i2005p3/no3_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r033i2005p3/talk_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r033i2005p3/si_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_033/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r033i2005p3/po4_Omon_MPI-ESM_rr033i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr033i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r089i2005p3/ph_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r089i2005p3/o2_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r089i2005p3/dcalc_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r089i2005p3/bfe_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r089i2005p3/co3_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r089i2005p3/co3satcalc_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r089i2005p3/no3_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r089i2005p3/talk_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r089i2005p3/si_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_089/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r089i2005p3/po4_Omon_MPI-ESM_rr089i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr089i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r021i2005p3/ph_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r021i2005p3/o2_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r021i2005p3/dcalc_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r021i2005p3/bfe_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r021i2005p3/co3_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r021i2005p3/co3satcalc_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r021i2005p3/no3_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r021i2005p3/talk_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r021i2005p3/si_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_021/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r021i2005p3/po4_Omon_MPI-ESM_rr021i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr021i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r061i2005p3/ph_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r061i2005p3/o2_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r061i2005p3/dcalc_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r061i2005p3/bfe_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r061i2005p3/co3_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r061i2005p3/co3satcalc_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r061i2005p3/no3_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r061i2005p3/talk_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r061i2005p3/si_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_061/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r061i2005p3/po4_Omon_MPI-ESM_rr061i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr061i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r080i2005p3/ph_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r080i2005p3/o2_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r080i2005p3/dcalc_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r080i2005p3/bfe_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r080i2005p3/co3_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r080i2005p3/co3satcalc_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r080i2005p3/no3_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r080i2005p3/talk_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r080i2005p3/si_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_080/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r080i2005p3/po4_Omon_MPI-ESM_rr080i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr080i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r052i2005p3/ph_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r052i2005p3/o2_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r052i2005p3/dcalc_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r052i2005p3/bfe_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r052i2005p3/co3_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r052i2005p3/co3satcalc_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r052i2005p3/no3_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r052i2005p3/talk_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r052i2005p3/si_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_052/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r052i2005p3/po4_Omon_MPI-ESM_rr052i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr052i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r088i2005p3/ph_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r088i2005p3/o2_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r088i2005p3/dcalc_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r088i2005p3/bfe_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r088i2005p3/co3_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r088i2005p3/co3satcalc_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r088i2005p3/no3_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r088i2005p3/talk_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r088i2005p3/si_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_088/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r088i2005p3/po4_Omon_MPI-ESM_rr088i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr088i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r082i2005p3/ph_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r082i2005p3/o2_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r082i2005p3/dcalc_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r082i2005p3/bfe_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r082i2005p3/co3_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r082i2005p3/co3satcalc_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r082i2005p3/no3_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r082i2005p3/talk_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r082i2005p3/si_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_082/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/po4/r082i2005p3/po4_Omon_MPI-ESM_rr082i2005p3_200601-209912.nc', 'variable': 'po4', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr082i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/ph/r074i2005p3/ph_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'ph', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/o2/r074i2005p3/o2_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'o2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/dcalc/r074i2005p3/dcalc_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'dcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/bfe/r074i2005p3/bfe_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'bfe', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3/r074i2005p3/co3_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'co3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/co3satcalc/r074i2005p3/co3satcalc_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'co3satcalc', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/no3/r074i2005p3/no3_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'no3', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/talk/r074i2005p3/talk_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'talk', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/prelim/rcp85_074/CMIP5/output/MPI-M/MPI-ESM/rcp85/mon/ocnBgchem/si/r074i2005p3/si_Omon_MPI-ESM_rr074i2005p3_200601-209912.nc', 'variable': 'si', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': 'rr074i2005p3', 'ensemble_member': '200601-209912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# ...
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r045i1850p3/fgo2_Omon_MPI-ESM_1pcr045i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr045i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r044i1850p3/fgo2_Omon_MPI-ESM_1pcr044i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr044i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r011i1850p3/fgo2_Omon_MPI-ESM_1pcr011i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr011i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r037i1850p3/fgo2_Omon_MPI-ESM_1pcr037i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr037i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r024i1850p3/fgo2_Omon_MPI-ESM_1pcr024i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr024i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r086i1850p3/fgo2_Omon_MPI-ESM_1pcr086i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr086i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r041i1850p3/fgo2_Omon_MPI-ESM_1pcr041i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr041i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r094i1850p3/fgo2_Omon_MPI-ESM_1pcr094i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr094i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r075i1850p3/fgo2_Omon_MPI-ESM_1pcr075i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr075i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r008i1850p3/fgo2_Omon_MPI-ESM_1pcr008i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr008i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r025i1850p3/fgo2_Omon_MPI-ESM_1pcr025i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr025i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r063i1850p3/fgo2_Omon_MPI-ESM_1pcr063i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr063i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r020i1850p3/fgo2_Omon_MPI-ESM_1pcr020i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr020i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r099i1850p3/fgo2_Omon_MPI-ESM_1pcr099i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr099i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r088i1850p3/fgo2_Omon_MPI-ESM_1pcr088i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr088i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r091i1850p3/fgo2_Omon_MPI-ESM_1pcr091i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr091i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r067i1850p3/fgo2_Omon_MPI-ESM_1pcr067i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr067i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r026i1850p3/fgo2_Omon_MPI-ESM_1pcr026i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr026i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r071i1850p3/fgo2_Omon_MPI-ESM_1pcr071i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr071i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r092i1850p3/fgo2_Omon_MPI-ESM_1pcr092i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr092i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r080i1850p3/fgo2_Omon_MPI-ESM_1pcr080i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr080i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r087i1850p3/fgo2_Omon_MPI-ESM_1pcr087i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr087i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r054i1850p3/fgo2_Omon_MPI-ESM_1pcr054i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr054i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r006i1850p3/fgo2_Omon_MPI-ESM_1pcr006i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr006i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r081i1850p3/fgo2_Omon_MPI-ESM_1pcr081i1850p3_185001-200012.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr081i1850p3', 'ensemble_member': '185001-200012', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r012i1850p3/fgo2_Omon_MPI-ESM_1pcr012i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr012i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r042i1850p3/fgo2_Omon_MPI-ESM_1pcr042i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr042i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r065i1850p3/fgo2_Omon_MPI-ESM_1pcr065i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr065i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r078i1850p3/fgo2_Omon_MPI-ESM_1pcr078i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr078i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r030i1850p3/fgo2_Omon_MPI-ESM_1pcr030i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr030i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r069i1850p3/fgo2_Omon_MPI-ESM_1pcr069i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr069i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r050i1850p3/fgo2_Omon_MPI-ESM_1pcr050i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr050i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r035i1850p3/fgo2_Omon_MPI-ESM_1pcr035i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr035i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r052i1850p3/fgo2_Omon_MPI-ESM_1pcr052i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr052i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r073i1850p3/fgo2_Omon_MPI-ESM_1pcr073i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr073i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r084i1850p3/fgo2_Omon_MPI-ESM_1pcr084i1850p3_185001-200012.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr084i1850p3', 'ensemble_member': '185001-200012', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r093i1850p3/fgo2_Omon_MPI-ESM_1pcr093i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr093i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r049i1850p3/fgo2_Omon_MPI-ESM_1pcr049i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr049i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r096i1850p3/fgo2_Omon_MPI-ESM_1pcr096i1850p3_185001-199912.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr096i1850p3', 'ensemble_member': '185001-199912', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r018i1850p3/fgo2_Omon_MPI-ESM_1pcr018i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr018i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r028i1850p3/fgo2_Omon_MPI-ESM_1pcr028i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr028i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r029i1850p3/fgo2_Omon_MPI-ESM_1pcr029i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr029i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r016i1850p3/fgo2_Omon_MPI-ESM_1pcr016i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr016i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r090i1850p3/fgo2_Omon_MPI-ESM_1pcr090i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr090i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r009i1850p3/fgo2_Omon_MPI-ESM_1pcr009i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr009i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/1pctCO2/mon/ocnBgchem/fgo2/r040i1850p3/fgo2_Omon_MPI-ESM_1pcr040i1850p3_185001-200512.nc', 'variable': 'fgo2', 'mip_table': 'Omon', 'model': 'MPI-ESM', 'experiment': '1pcr040i1850p3', 'ensemble_member': '185001-200512', 'frequency': 'mon', 'modeling_realm': 'ocnBgchem', 'version': 'v0'}
# CPU times: user 4.17 s, sys: 159 ms, total: 4.33 s
# Wall time: 4.23 s

# %%
entries[10]
# Out:
# {'path': '/work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM/piControl/mon/atmos/prsn/r001i1850p3/v20190123/prsn_Amon_MPI-ESM_piControl_r001i1850p3_340001-349912.nc',
#  'variable': 'prsn',
#  'mip_table': 'Amon',
#  'model': 'MPI-ESM',
#  'experiment': 'piControl',
#  'ensemble_member': 'r001i1850p3',
#  'temporal_subset': '340001-349912',
#  'frequency': 'mon',
#  'modeling_realm': 'atmos',
#  'version': 'v20190123',
#  'institute': 'MPI-M',
#  'product_id': 'output1'}

# %%
len(entries)
# Out:
# 70124

# %%
df = pd.DataFrame(entries)
df = df.drop_duplicates(subset=['path'], keep='last').reset_index(drop=True)
df.head()
# Out:
#                                                 path variable mip_table  \
# 0  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 1  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 2  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 3  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 4  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
#
#      model experiment ensemble_member temporal_subset frequency  \
# 0  MPI-ESM  piControl     r001i1850p3   310001-319912       mon
# 1  MPI-ESM  piControl     r001i1850p3   380001-385012       mon
# 2  MPI-ESM  piControl     r001i1850p3   230001-239912       mon
# 3  MPI-ESM  piControl     r001i1850p3   280001-289912       mon
# 4  MPI-ESM  piControl     r001i1850p3   190001-199912       mon
#
#   modeling_realm    version institute product_id
# 0          atmos  v20190123     MPI-M    output1
# 1          atmos  v20190123     MPI-M    output1
# 2          atmos  v20190123     MPI-M    output1
# 3          atmos  v20190123     MPI-M    output1
# 4          atmos  v20190123     MPI-M    output1

# %%
len(df)
# Out:
# 70124

# %%
# Some entries are invalid
invalids = df[~df.product_id.isin(products)]
invalids
#df = df[df.activity_id.isin(activity_ids)]
# Out:
#                                                     path variable mip_table  \
# 14170  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...       ph      Omon
# 14171  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...       o2      Omon
# 14172  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...    dcalc      Omon
# 14173  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...      bfe      Omon
# 14174  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...      co3      Omon
# ...                                                  ...      ...       ...
# 38350  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     fgo2      Omon
# 38352  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     fgo2      Omon
# 38354  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     fgo2      Omon
# 38356  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     fgo2      Omon
# 38358  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     fgo2      Omon
#
#          model      experiment ensemble_member temporal_subset frequency  \
# 14170  MPI-ESM    rr036i2005p3   200601-209912             NaN       mon
# 14171  MPI-ESM    rr036i2005p3   200601-209912             NaN       mon
# 14172  MPI-ESM    rr036i2005p3   200601-209912             NaN       mon
# 14173  MPI-ESM    rr036i2005p3   200601-209912             NaN       mon
# 14174  MPI-ESM    rr036i2005p3   200601-209912             NaN       mon
# ...        ...             ...             ...             ...       ...
# 38350  MPI-ESM  1pcr029i1850p3   185001-200512             NaN       mon
# 38352  MPI-ESM  1pcr016i1850p3   185001-200512             NaN       mon
# 38354  MPI-ESM  1pcr090i1850p3   185001-200512             NaN       mon
# 38356  MPI-ESM  1pcr009i1850p3   185001-200512             NaN       mon
# 38358  MPI-ESM  1pcr040i1850p3   185001-200512             NaN       mon
#
#       modeling_realm version institute product_id
# 14170      ocnBgchem      v0       NaN        NaN
# 14171      ocnBgchem      v0       NaN        NaN
# 14172      ocnBgchem      v0       NaN        NaN
# 14173      ocnBgchem      v0       NaN        NaN
# 14174      ocnBgchem      v0       NaN        NaN
# ...              ...     ...       ...        ...
# 38350      ocnBgchem      v0       NaN        NaN
# 38352      ocnBgchem      v0       NaN        NaN
# 38354      ocnBgchem      v0       NaN        NaN
# 38356      ocnBgchem      v0       NaN        NaN
# 38358      ocnBgchem      v0       NaN        NaN
#
# [2336 rows x 12 columns]

# %%
df = df[df.product_id.isin(products)]
len(df)
# Out:
# 67788

# %%
df.ensemble_member.unique()
# Out:
# array(['r001i1850p3', 'r097i2005p3', 'r046i2005p3', 'r001i2005p3',
#        'r086i2005p3', 'r002i2005p3', 'r015i2005p3', 'r024i2005p3',
#        'r018i2005p3', 'r083i2005p3', 'r032i2005p3', 'r007i2005p3',
#        'r013i2005p3', 'r019i2005p3', 'r068i2005p3', 'r082i2005p3',
#        'r016i2005p3', 'r056i2005p3', 'r031i2005p3', 'r064i2005p3',
#        'r017i2005p3', 'r069i2005p3', 'r045i2005p3', 'r070i2005p3',
#        'r072i2005p3', 'r099i2005p3', 'r067i2005p3', 'r043i2005p3',
#        'r081i2005p3', 'r094i2005p3', 'r051i2005p3', 'r057i2005p3',
#        'r063i2005p3', 'r009i2005p3', 'r095i2005p3', 'r042i2005p3',
#        'r030i2005p3', 'r079i2005p3', 'r050i2005p3', 'r073i2005p3',
#        'r025i2005p3', 'r084i2005p3', 'r036i2005p3', 'r003i2005p3',
#        'r040i2005p3', 'r089i2005p3', 'r066i2005p3', 'r028i2005p3',
#        'r062i2005p3', 'r090i2005p3', 'r078i2005p3', 'r011i2005p3',
#        'r100i2005p3', 'r087i2005p3', 'r044i2005p3', 'r047i2005p3',
#        'r076i2005p3', 'r098i2005p3', 'r065i2005p3', 'r055i2005p3',
#        'r012i2005p3', 'r054i2005p3', 'r077i2005p3', 'r041i2005p3',
#        'r092i2005p3', 'r035i2005p3', 'r010i2005p3', 'r026i2005p3',
#        'r049i2005p3', 'r088i2005p3', 'r014i2005p3', 'r034i2005p3',
#        'r008i2005p3', 'r091i2005p3', 'r033i2005p3', 'r021i2005p3',
#        'r053i2005p3', 'r085i2005p3', 'r061i2005p3', 'r071i2005p3',
#        'r023i2005p3', 'r022i2005p3', 'r027i2005p3', 'r038i2005p3',
#        'r075i2005p3', 'r096i2005p3', 'r005i2005p3', 'r059i2005p3',
#        'r074i2005p3', 'r037i2005p3', 'r052i2005p3', 'r080i2005p3',
#        'r039i2005p3', 'r048i2005p3', 'r004i2005p3', 'r058i2005p3',
#        'r093i2005p3', 'r029i2005p3', 'r060i2005p3', 'r020i2005p3',
#        'r006i2005p3', 'r004i1850p3', 'r100i1850p3', 'r074i1850p3',
#        'r057i1850p3', 'r079i1850p3', 'r022i1850p3', 'r058i1850p3',
#        'r043i1850p3', 'r098i1850p3', 'r002i1850p3', 'r046i1850p3',
#        'r010i1850p3', 'r047i1850p3', 'r060i1850p3', 'r048i1850p3',
#        'r032i1850p3', 'r034i1850p3', 'r089i1850p3', 'r015i1850p3',
#        'r095i1850p3', 'r072i1850p3', 'r066i1850p3', 'r068i1850p3',
#        'r033i1850p3', 'r036i1850p3', 'r023i1850p3', 'r070i1850p3',
#        'r064i1850p3', 'r039i1850p3', 'r059i1850p3', 'r056i1850p3',
#        'r062i1850p3', 'r077i1850p3', 'r031i1850p3', 'r005i1850p3',
#        'r053i1850p3', 'r061i1850p3', 'r027i1850p3', 'r082i1850p3',
#        'r051i1850p3', 'r014i1850p3', 'r055i1850p3', 'r019i1850p3',
#        'r097i1850p3', 'r013i1850p3', 'r085i1850p3', 'r017i1850p3',
#        'r007i1850p3', 'r021i1850p3', 'r076i1850p3', 'r083i1850p3',
#        'r038i1850p3', 'r045i1850p3', 'r044i1850p3', 'r011i1850p3',
#        'r037i1850p3', 'r024i1850p3', 'r086i1850p3', 'r041i1850p3',
#        'r094i1850p3', 'r075i1850p3', 'r008i1850p3', 'r025i1850p3',
#        'r063i1850p3', 'r020i1850p3', 'r099i1850p3', 'r088i1850p3',
#        'r091i1850p3', 'r067i1850p3', 'r026i1850p3', 'r071i1850p3',
#        'r092i1850p3', 'r080i1850p3', 'r087i1850p3', 'r054i1850p3',
#        'r006i1850p3', 'r003i1850p3', 'r081i1850p3', 'r012i1850p3',
#        'r042i1850p3', 'r065i1850p3', 'r078i1850p3', 'r030i1850p3',
#        'r069i1850p3', 'r050i1850p3', 'r035i1850p3', 'r052i1850p3',
#        'r073i1850p3', 'r084i1850p3', 'r093i1850p3', 'r049i1850p3',
#        'r096i1850p3', 'r018i1850p3', 'r028i1850p3', 'r029i1850p3',
#        'r016i1850p3', 'r090i1850p3', 'r009i1850p3', 'r040i1850p3',
#        'r3i1850p3'], dtype=object)

# %% [markdown]
# ## Pick the latest versions only

# %%
grpby = list(set(df.columns.tolist()) - {'path', 'version'})
groups = df.groupby(grpby)

# %%
# %%time
idx_to_remove = []
for _, group in groups:
    if group.version.nunique() > 1:
        idx_to_remove.extend(group.sort_values(by=['version'], ascending=False).index[1:].values.tolist())
# Out:
# CPU times: user 27.2 s, sys: 280 ms, total: 27.5 s
# Wall time: 27.1 s

# %%
len(idx_to_remove)
# Out:
# 4

# %%
len(df)
# Out:
# 67788

# %%
df1 = df.copy()
df = df.drop(index=idx_to_remove)
len(df)
# Out:
# 67784

# %%
df.head()
# Out:
#                                                 path variable mip_table  \
# 0  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 1  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 2  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 3  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
# 4  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...     prsn      Amon
#
#      model experiment ensemble_member temporal_subset frequency  \
# 0  MPI-ESM  piControl     r001i1850p3   310001-319912       mon
# 1  MPI-ESM  piControl     r001i1850p3   380001-385012       mon
# 2  MPI-ESM  piControl     r001i1850p3   230001-239912       mon
# 3  MPI-ESM  piControl     r001i1850p3   280001-289912       mon
# 4  MPI-ESM  piControl     r001i1850p3   190001-199912       mon
#
#   modeling_realm    version institute product_id
# 0          atmos  v20190123     MPI-M    output1
# 1          atmos  v20190123     MPI-M    output1
# 2          atmos  v20190123     MPI-M    output1
# 3          atmos  v20190123     MPI-M    output1
# 4          atmos  v20190123     MPI-M    output1

# %%
df.columns.shape
# Out:
# (12,)

# %%
# Re-arange columns
columns = ["product_id", "institute", "model", "experiment", "frequency", 
           "modeling_realm", "mip_table", "ensemble_member", "variable", 
           "temporal_subset", "version", "path"]
df = df[columns]
df.head()
# Out:
#   product_id institute    model experiment frequency modeling_realm mip_table  \
# 0    output1     MPI-M  MPI-ESM  piControl       mon          atmos      Amon
# 1    output1     MPI-M  MPI-ESM  piControl       mon          atmos      Amon
# 2    output1     MPI-M  MPI-ESM  piControl       mon          atmos      Amon
# 3    output1     MPI-M  MPI-ESM  piControl       mon          atmos      Amon
# 4    output1     MPI-M  MPI-ESM  piControl       mon          atmos      Amon
#
#   ensemble_member variable temporal_subset    version  \
# 0     r001i1850p3     prsn   310001-319912  v20190123
# 1     r001i1850p3     prsn   380001-385012  v20190123
# 2     r001i1850p3     prsn   230001-239912  v20190123
# 3     r001i1850p3     prsn   280001-289912  v20190123
# 4     r001i1850p3     prsn   190001-199912  v20190123
#
#                                                 path
# 0  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 1  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 2  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 3  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 4  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...

# %% [markdown]
# #### change ensemble member id

# %%
# backup
df2=df.copy()
#df = df2

# %%
df['ensemble_member'] = df['ensemble_member'].str.replace('i1850p3','')
df['ensemble_member'] = df['ensemble_member'].str.replace('i2005p3','')
df['ensemble_member'] = df['ensemble_member'].str.replace('r','')
df['ensemble_member'] = df.ensemble_member.astype('int')

# %%
df
# Out:
#       product_id institute    model experiment frequency modeling_realm  \
# 0        output1     MPI-M  MPI-ESM  piControl       mon          atmos
# 1        output1     MPI-M  MPI-ESM  piControl       mon          atmos
# 2        output1     MPI-M  MPI-ESM  piControl       mon          atmos
# 3        output1     MPI-M  MPI-ESM  piControl       mon          atmos
# 4        output1     MPI-M  MPI-ESM  piControl       mon          atmos
# ...          ...       ...      ...        ...       ...            ...
# 70119    output1     MPI-M  MPI-ESM      rcp26        yr      ocnBgchem
# 70120    output1     MPI-M  MPI-ESM      rcp26        yr      ocnBgchem
# 70121    output1     MPI-M  MPI-ESM      rcp26        yr      ocnBgchem
# 70122    output1     MPI-M  MPI-ESM      rcp26        yr      ocnBgchem
# 70123    output1     MPI-M  MPI-ESM      rcp26        yr      ocnBgchem
#
#       mip_table  ensemble_member variable temporal_subset    version  \
# 0          Amon                1     prsn   310001-319912  v20190123
# 1          Amon                1     prsn   380001-385012  v20190123
# 2          Amon                1     prsn   230001-239912  v20190123
# 3          Amon                1     prsn   280001-289912  v20190123
# 4          Amon                1     prsn   190001-199912  v20190123
# ...         ...              ...      ...             ...        ...
# 70119       Oyr               93      po4       2006-2099  v20190123
# 70120       Oyr               29      po4       2006-2099  v20190123
# 70121       Oyr               60      po4       2006-2099  v20190123
# 70122       Oyr               20      po4       2006-2099  v20190123
# 70123       Oyr                6      po4       2006-2099  v20190123
#
#                                                     path
# 0      /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 1      /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 2      /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 3      /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 4      /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# ...                                                  ...
# 70119  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 70120  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 70121  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 70122  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
# 70123  /work/mh1007/CMOR/MPI-GE/output1/MPI-M/MPI-ESM...
#
# [67784 rows x 12 columns]

# %%
df.experiment.unique()
# Out:
# array(['piControl', 'rcp85', 'historical', '1pctCO2', 'rcp45', 'rcp26'],
#       dtype=object)

# %%
df.mip_table.unique()
# Out:
# array(['Amon', 'Omon', 'Oyr', 'Lmon', 'OImon'], dtype=object)

# %%
df.variable.unique()
# Out:
# array(['prsn', 'rsus', 'vas', 'wap', 'uas', 'hfls', 'rlus', 'sfcWind',
#        'rlut', 'rlutcs', 'zg', 'clt', 'ta', 'rsdt', 'va', 'ua', 'hfss',
#        'ps', 'prc', 'pr', 'rsut', 'hus', 'ts', 'tas', 'psl', 'tauu',
#        'evspsbl', 'tauv', 'clivi', 'clwvi', 'prw', 'wmo', 'umo', 'vmo',
#        'so', 'thetao', 'uo', 'vo', 'rhopoto', 'dpco2', 'spco2', 'intpp',
#        'fgco2', 'fgo2', 'dissic', 'o2', 'co3', 'no3', 'talk', 'si', 'po4',
#        'cVegLut', 'grassFracC4', 'cLitter', 'grassFrac', 'cropFracC4',
#        'et', 'mrsos', 'rsds', 'snm', 'fracLut', 'grassFracC3', 'mrro',
#        'cVegGrass', 'rhGrass', 'raTree', 'npp', 'nwdFracLut', 'cSoilTree',
#        'vegFrac', 'gppGrass', 'nppGrass', 'ra', 'lai', 'cropFracC3',
#        'snc', 'nbp', 'shrubFrac', 'cropFrac', 'gppShrub', 'c4PftFrac',
#        'nppTree', 'nppLut', 'pastureFrac', 'snw', 'tran', 'nep', 'cVeg',
#        'rh', 'cLitterGrass', 'mrros', 'baresoilFrac', 'gpp', 'cSoilLut',
#        'raShrub', 'mrso', 'gppTree', 'rlds', 'tsl', 'cSoilGrass',
#        'pastureFracC3', 'rhLut', 'co2mass', 'rhSoil', 'raLut', 'cLand',
#        'pastureFracC4', 'nppShrub', 'fLuc', 'rhTree', 'cSoilShrub',
#        'rhShrub', 'raGrass', 'cLitterLut', 'cSoil', 'fFire', 'cVegShrub',
#        'cVegTree', 'treeFrac', 'mrsol', 'laiLut', 'cLitterShrub',
#        'cLitterTree', 'gppLut', 'c3PftFrac', 'sic', 'sit', 'snd', 'ph',
#        'dcalc', 'phyc', 'epsi100', 'epcalc100', 'co3satcalc'],
#       dtype=object)

# %%
df.to_csv("../catalogs/mistral-MPI-GE.csv.gz", compression="gzip", index=False)
